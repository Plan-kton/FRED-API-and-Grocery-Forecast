# %% [markdown]
# # 📊 Matplotlib Cheat Sheet
#
# Matplotlib is a powerful library for creating static, animated, and interactive visualizations in Python.
#
# ## 🔹 Importing Matplotlib
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# ```
#
# ---
# ## **1️⃣ Simple (State-Based) Approach**
# The **state-based interface** uses `plt.` directly and lets Matplotlib handle figure and axes creation automatically. This is best for **quick, simple plots**.
#
# ### 📈 **Basic Line Plot**
# ```python
# x = np.linspace(0, 10, 100)
# y = np.sin(x)
#
# plt.plot(x, y, label='sin(x)')
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.title('Basic Line Plot')
# plt.legend()
# plt.show()
# ```
#
# ### 📊 **Bar Chart**
# ```python
# categories = ['A', 'B', 'C', 'D']
# values = [10, 15, 7, 12]
#
# plt.bar(categories, values, color='skyblue')
# plt.xlabel('Categories')
# plt.ylabel('Values')
# plt.title('Bar Chart Example')
# plt.show()
# ```
#
# ### 🟢 **Scatter Plot**
# ```python
# x = np.random.rand(50)
# y = np.random.rand(50)
#
# plt.scatter(x, y, color='green', alpha=0.6)
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.title('Scatter Plot Example')
# plt.show()
# ```
#
# ### 📊 **Histogram**
# ```python
# data = np.random.randn(1000)
#
# plt.hist(data, bins=30, color='purple', alpha=0.7)
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.title('Histogram Example')
# plt.show()
# ```
#
# ---
# ## **2️⃣ Object-Oriented (OOP) Approach**
# The **OOP interface** gives more control by explicitly managing **Figure** and **Axes** objects. This is best for **multiple subplots and advanced customization**.
#
# ### **📈 Line Plot (OOP Approach)**
# ```python
# fig, ax = plt.subplots(figsize=(8,5))  # Create figure and axis
#
# x = np.linspace(0, 10, 100)
# y = np.sin(x)
#
# ax.plot(x, y, label='sin(x)')
# ax.set_xlabel('X-axis')
# ax.set_ylabel('Y-axis')
# ax.set_title('Basic Line Plot')
# ax.legend()
#
# plt.show()
# ```
#
# ### **📊 Bar Chart (OOP Approach)**
# ```python
# fig, ax = plt.subplots()
#
# categories = ['A', 'B', 'C', 'D']
# values = [10, 15, 7, 12]
#
# ax.bar(categories, values, color='skyblue')
# ax.set_xlabel('Categories')
# ax.set_ylabel('Values')
# ax.set_title('Bar Chart Example')
#
# plt.show()
# ```
#
# ### **📊 Multiple Subplots**
# ```python
# fig, ax = plt.subplots(2, 2, figsize=(8, 6))
#
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
#
# ax[0, 0].plot(x, y1, 'r')
# ax[0, 0].set_title('Sine Wave')
#
# ax[0, 1].plot(x, y2, 'b')
# ax[0, 1].set_title('Cosine Wave')
#
# ax[1, 0].hist(np.random.randn(100), bins=20, color='g')
# ax[1, 0].set_title('Histogram')
#
# ax[1, 1].scatter(np.random.rand(50), np.random.rand(50), color='k')
# ax[1, 1].set_title('Scatter Plot')
#
# plt.tight_layout()
# plt.show()
# ```
#
# ### 🎨 **Customizing Plots (OOP Approach)**
# ```python
# fig, ax = plt.subplots()
#
# x = np.linspace(0, 10, 100)
# y = np.sin(x)
#
# ax.plot(x, y, linestyle='--', linewidth=2, color='red', marker='o', markersize=5)
# ax.set_xlabel('X-axis')
# ax.set_ylabel('Y-axis')
# ax.set_title('Customized Plot')
#
# plt.show()
# ```
#
# ### 🔄 **Saving a Figure**
# ```python
# fig, ax = plt.subplots()
# ax.plot(x, y)
# fig.savefig('plot.png', dpi=300, bbox_inches='tight')
# ```
#
# ### 🏁 **Show All Open Figures**
# ```python
# plt.show()
# ```
#
# ---
# ## **🚀 Key Takeaways**
# | Feature | Simple (`plt.`) | Object-Oriented (`fig, ax`) |
# |---------|----------------|--------------------------|
# | **Best for** | Quick, simple plots | Advanced, multiple subplots |
# | **Flexibility** | Limited customization | More control over figures & axes |
# | **Multiple subplots** | ❌ No | ✅ Yes |
# | **Explicit control** | ❌ No | ✅ Yes |
# | **Ease of use** | ✅ Yes | ❌ More code |
#
# Choose **Simple (`plt.`)** for **quick plots**, and **Object-Oriented (`fig, ax`)** for **better control and multiple subplots**! 🚀

# %% [markdown]
# # 📊 Seaborn Cheat Sheet
#
# Seaborn is a Python library for statistical data visualization, built on Matplotlib. It provides **beautiful, high-level functions** for plotting different types of data.
#
# ---
# ## **1️⃣ Importing Seaborn**
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
# ---
# ## **2️⃣ Loading Example Datasets**
# ```python
# # Load built-in dataset
# df = sns.load_dataset("tips")  # Example dataset
# df.head()  # View first few rows
# ```
#
# ---
# ## **3️⃣ Basic Plot Customization**
# ```python
# sns.set_style("darkgrid")  # Set background style
# sns.set_palette("pastel")  # Set color palette
# ```
#
# ---
# ## **4️⃣ Distribution Plots**
# ### **🔹 Histogram (`histplot`)**
# ```python
# sns.histplot(df["total_bill"], bins=20, kde=True)
# plt.show()
# ```
# ### **🔹 Kernel Density Estimation (`kdeplot`)**
# ```python
# sns.kdeplot(df["total_bill"], shade=True)
# plt.show()
# ```
#
# ---
# ## **5️⃣ Categorical Plots**
# ### **🔹 Bar Plot (`barplot`)**
# ```python
# sns.barplot(x="day", y="total_bill", data=df)
# plt.show()
# ```
# ### **🔹 Box Plot (`boxplot`)**
# ```python
# sns.boxplot(x="day", y="total_bill", data=df)
# plt.show()
# ```
# ### **🔹 Violin Plot (`violinplot`)**
# ```python
# sns.violinplot(x="day", y="total_bill", data=df)
# plt.show()
# ```
#
# ---
# ## **6️⃣ Relational Plots**
# ### **🔹 Scatter Plot (`scatterplot`)**
# ```python
# sns.scatterplot(x="total_bill", y="tip", hue="sex", data=df)
# plt.show()
# ```
# ### **🔹 Line Plot (`lineplot`)**
# ```python
# sns.lineplot(x="size", y="total_bill", data=df)
# plt.show()
# ```
#
# ---
# ## **7️⃣ Pairwise Plots**
# ### **🔹 Pair Plot (`pairplot`)**
# ```python
# sns.pairplot(df, hue="sex")
# plt.show()
# ```
# ### **🔹 Heatmap (`heatmap`)**
# ```python
# sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# plt.show()
# ```
#
# ---
# ## **8️⃣ Regression Plots**
# ### **🔹 Regression Plot (`regplot`)**
# ```python
# sns.regplot(x="total_bill", y="tip", data=df)
# plt.show()
# ```
# ### **🔹 LM Plot (`lmplot`)**
# ```python
# sns.lmplot(x="total_bill", y="tip", hue="sex", data=df)
# plt.show()
# ```
#
# ---
# ## **9️⃣ Styling & Customization**
# ```python
# sns.set_theme(style="whitegrid", palette="muted")  # Set theme
# plt.figure(figsize=(10, 6))  # Change figure size
# sns.despine()  # Remove top and right borders
# ```
#
# ---
# ## **🔟 Saving Plots**
# ```python
# sns.histplot(df["total_bill"], bins=20)
# plt.savefig("histogram.png", dpi=300)
# ```
#
# ---
# ## **🚀 Summary of Key Seaborn Functions**
# | Function | Use |
# |----------|-----|
# | `sns.histplot()` | Histogram |
# | `sns.kdeplot()` | Density plot |
# | `sns.barplot()` | Categorical bar chart |
# | `sns.boxplot()` | Box plot |
# | `sns.violinplot()` | Violin plot |
# | `sns.scatterplot()` | Scatter plot |
# | `sns.lineplot()` | Line plot |
# | `sns.pairplot()` | Pairwise plot |
# | `sns.heatmap()` | Correlation heatmap |
# | `sns.regplot()` | Regression plot |
#
# This **Seaborn Cheat Sheet** provides quick references for the most-used Seaborn functions! 🚀 Happy plotting! 😊

# %%
#Basic Line Plot
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label='sin(x)') #plot = line
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic Line Plot')
plt.legend()
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 15, 7, 12]

plt.bar(categories, values, color='skyblue') #bar chart
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, color='green', alpha=0.6)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')
plt.show()

# %%
data = np.random.randn(1000)

plt.hist(data, bins=30, color='purple', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6))  #the ax creates a numpy array that is used to identify each of the axis and charts, eg, ax[0 ,0] is first row and first chart

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

ax[0, 0].plot(x, y1, 'r')
ax[0, 0].set_title('Sine Wave')

ax[0, 1].plot(x, y2, 'b')
ax[0, 1].set_title('Cosine Wave')

ax[1, 0].hist(np.random.randn(100), bins=20, color='g')
ax[1, 0].set_title('Histogram')

ax[1, 1].scatter(np.random.rand(50), np.random.rand(50), color='k')
ax[1, 1].set_title('Scatter Plot')

plt.tight_layout()
plt.show()

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
rand1 = np.random.rand(50)
rand2 = np.random.rand(50)

figure = plt.figure(figsize=(16, 4))
subplot1 = figure.add_subplot(141)
subplot2 = figure.add_subplot(142)
subplot3 = figure.add_subplot(143)
subplot4 = figure.add_subplot(144)
subplot1.plot(x, y1, color='red')
subplot2.plot(x, y2, color='blue')
subplot3.hist(rand1, facecolor='green', edgecolor='black')
subplot4.scatter(rand1, rand2, color='black')
subplot1.set_xlim([0, 10])
subplot2.set_xlim([0, 10])
#subplot3.set_xlim([-2, 3])
#subplot4.set_xlim([0, 1])
figure.suptitle('Fun With Charts')
subplot1.set_title('Sine')
subplot2.set_title('Cosine')
subplot3.set_title('Histogram')
subplot4.set_title('Scatter')
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, linestyle='--', linewidth=2, color='red', marker='o', markersize=5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Customized Plot')
plt.show()
