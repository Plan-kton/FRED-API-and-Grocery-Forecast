# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file
df = pd.read_csv('grocery_dataset.csv')
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df.set_index('date')
df = df[df.index >= '2000-01-01']

# %% [markdown]
# ### Describe the Data ###

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 301 entries, 2000-01-31 to 2025-01-31
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cpi_fah         301 non-null    float64
#  1   grocery_sales   301 non-null    float64
#  2   rdi             301 non-null    float64
#  3   home_price      301 non-null    float64
#  4   cons_sent       301 non-null    float64
#  5   unrate          301 non-null    float64
#  6   initial_claims  301 non-null    float64
#  7   gdp             301 non-null    float64
#  8   oil_prices      301 non-null    float64
#  9   ppi_food_feed   301 non-null    float64
#  10  ppi_food_final  301 non-null    float64
#  11  hourly_wages    301 non-null    float64
#  12  ppi_food_mfg    301 non-null    float64
#  13  ppi_cons_food   301 non-null    float64
# dtypes: float64(14)
# memory usage: 35.3 KB

# %%
print(df.index)
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-04-30', '2024-05-31', '2024-06-30', '2024-07-31',
#                '2024-08-31', '2024-09-30', '2024-10-31', '2024-11-30',
#                '2024-12-31', '2025-01-31'],
#               dtype='datetime64[ns]', name='date', length=301, freq=None)

# %%
df.describe().T
# Out:
#                 count           mean            std         min         25%  \
# cpi_fah         301.0     226.333528      37.896008     165.300     192.300
# grocery_sales   301.0   49433.651163   12428.846987   32239.000   38891.000
# rdi             301.0   13435.435880    2273.886152    9799.900   11737.000
# home_price      301.0     183.685166      58.227259     100.000     143.963
# cons_sent       301.0      82.829568      13.234902      50.000      72.500
# unrate          301.0       5.690033       1.959975       3.400       4.200
# initial_claims  301.0  381990.033223  401959.902520  187000.000  248000.000
# gdp             301.0   18059.626306    2660.945477   13878.147   16298.262
# oil_prices      301.0      63.937110      25.384860      19.230      45.060
# ppi_food_feed   301.0     192.151757      38.345289     131.000     153.900
# ppi_food_final  301.0     114.717841      16.443423     100.300     100.300
# ...

# %% [markdown]
# ### Missing Values, Duplicates, and Outliers ###

# %%
# Count total missing values per column
missing_counts = df.isna().sum()

# Show only columns with missing values
missing_counts = missing_counts[missing_counts > 0]

missing_counts
# Out:
# Series([], dtype: int64)

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Identify outliers using IQR
cols = df.columns.tolist()

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)

IQR = Q3 - Q1

lower_whisker = Q1 - 1.5 * IQR
upper_whisker = Q3 + 1.5 * IQR

IQR_df = pd.DataFrame(
    {'Column': Q1.index,                        # Column names
    'Q1 (25th percentile)': Q1.values,          # Q1 values
    'Q3 (75th percentile)': Q3.values,          # Q3 values
    'IQR': IQR.values,                          # Interquartile range
    'Lower Whisker': lower_whisker.values,      # Lower whisker
    'Upper Whisker': upper_whisker.values})      # Upper whisker

#This provides the percent of values above or below the whiskers
((df[cols] < lower_whisker) | (df[cols] > upper_whisker)).sum() / len(df) * 100
# Out:
# cpi_fah            0.000000
# grocery_sales      0.000000
# rdi                0.000000
# home_price        10.299003
# cons_sent          0.000000
# unrate             4.318937
# initial_claims     5.315615
# gdp                0.000000
# oil_prices         0.332226
# ppi_food_feed      0.000000
# ppi_food_final    11.295681
# hourly_wages       0.000000
# ppi_food_mfg       0.000000
# ppi_cons_food      0.000000
# dtype: float64

# %% [markdown]
# ### Visualizations ###

# %%
# Select the variables to plot (excluding 'date')
var_list = df.columns.tolist()

# Create a 2-column, 7-row grid of subplots
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(15, 25))  # 2 wide × 7 down

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and plot
for i, col in enumerate(var_list):
    ax = axes[i]  # Select the subplot
    ax.plot(df.index, df[col], label=col, linewidth=2)
    
    # Customize the subplot
    ax.set_title(col, fontsize=12)
    ax.set_xlabel("Date", fontsize=10)
    ax.set_ylabel("Value", fontsize=10)
    ax.grid(True)
    ax.legend()

# Adjust layout for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Select independent variables (excluding index)
var_list = df.columns.tolist()  # Since 'date' is index, it's not included

# Create a grid of subplots (2 columns × enough rows for all variables)
num_vars = len(var_list)
rows = (num_vars // 2) + (num_vars % 2)  # Ensures enough rows for all variables

fig, axes = plt.subplots(nrows=rows, ncols=2, figsize=(15, 5 * rows))  # Dynamically sized

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and create scatter plots
for i, col in enumerate(var_list):
    ax = axes[i]
    ax.scatter(df[col], df['grocery_sales'], color='green', alpha=0.6)
    ax.set_xlabel(col, fontsize=10)
    ax.set_ylabel('Grocery Sales', fontsize=10)
    ax.set_title(f'Scatter Plot: {col} vs Grocery Sales')

# Hide empty subplots if `var_list` has an odd number of elements
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and show all plots
plt.tight_layout()
plt.show()

# %%
# Select independent variables (excluding index)
var_list = df.columns.tolist()  # Since 'date' is index, it's not included

# Create a grid of subplots (2 columns × enough rows for all variables)
num_vars = len(var_list)
rows = (num_vars // 2) + (num_vars % 2)  # Ensures enough rows for all variables

fig, axes = plt.subplots(nrows=rows, ncols=2, figsize=(15, 5 * rows))  # Dynamically sized

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and create scatter plots
for i, col in enumerate(var_list):
    ax = axes[i]
    ax.scatter(df[col], df['cpi_fah'], color='red', alpha=0.6)
    ax.set_xlabel(col, fontsize=10)
    ax.set_ylabel('Food Inflation', fontsize=10)
    ax.set_title(f'Scatter Plot: {col} vs Food Inflation')

# Hide empty subplots if `var_list` has an odd number of elements
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and show all plots
plt.tight_layout()
plt.show()

# %%
# Compute the correlation matrix
df_corr = df.select_dtypes(include=['number']).corr()

plt.figure(figsize=(10, 6))
sns.heatmap(df_corr, annot=True, cbar=False, cmap="coolwarm")
plt.show()

# %% [markdown]
# ### Feature Creation ###

# %%
#feature creation

# Create first difference variables (applies to all numeric columns)
df_diff = df.diff().add_suffix('_diff')

# Create YOY variables (applies to all numeric columns)
df_yoy = df.pct_change(periods=12).add_suffix('_yoy') * 100  # Converts to percentage

# Create dummy1 for dates between 2/29/2020 and 4/30/2020. A boolean consition with a .astype(int) will return a 1 for True and 0 for false
df['covid1'] = ((df.index >= '2020-02-29') & (df.index <= '2020-04-30')).astype(int)

# Create dummy2 for dates between 5/31/2020 and 10/31/2020
df['covid2'] = ((df.index >= '2020-05-31') & (df.index <= '2020-10-31')).astype(int)

df.loc['2020-03-31'] = 61000

# %% [markdown]
# ### Lagged Variable Analysis ###

# %%
# Dictionary to store lagged variables
lagged_vars = {}

# Loop over lag values (1 to 12)
for lag in range(1, 13):  
    print(f"Processing lag {lag}...")  # Optional: Progress update
    
    # Create lagged versions for all columns and store them in the dictionary
    for col in df.columns:
        new_col_name = f"{col}_lag{lag}"  # Create column name dynamically
        lagged_vars[new_col_name] = df[col].shift(lag)  # Shift column
    
# Convert the dictionary to a DataFrame (bulk operation)
df_lags = pd.DataFrame(lagged_vars)

# Efficiently merge all lagged variables into the main DataFrame
df = pd.concat([df, df_lags, df_diff, df_yoy], axis=1)

print("✅ Lagged variables added successfully!")
# Out:
# Processing lag 1...
# Processing lag 2...
# Processing lag 3...
# Processing lag 4...
# Processing lag 5...
# Processing lag 6...
# Processing lag 7...
# Processing lag 8...
# Processing lag 9...
# Processing lag 10...
# Processing lag 11...
# Processing lag 12...
# ✅ Lagged variables added successfully!

# %%
# Define dependent variable
dep_var = 'grocery_sales'

# Extract unique independent variable names without lag numbers
independent_vars = ['cpi_fah', 'rdi', 'home_price', 'cons_sent', 'unrate', 'initial_claims', 'gdp']  # List all base independent vars before lagging

# Loop through each independent variable to find all lagged versions
for var in independent_vars:
    lagged_vars = df.filter(like=var + '_lag').columns.tolist()  # Select all lags dynamically
    var_list = [dep_var] + lagged_vars  # Ensure dependent variable is first
    
    # Compute correlation matrix
    corr_matrix = df[var_list].corr()
    
    # Print the correlation matrix for each independent variable group
    print(f"📊 Correlation Matrix for {var} lags vs {dep_var}")
    print(corr_matrix)
    print("\n" + "="*50 + "\n")  # Separator for readability
# Out:
# 📊 Correlation Matrix for cpi_fah lags vs grocery_sales
#                grocery_sales  cpi_fah_lag1  cpi_fah_lag2  cpi_fah_lag3  \
# grocery_sales       1.000000      0.079118      0.081202      0.074286
# cpi_fah_lag1        0.079118      1.000000     -0.002526     -0.002513
# cpi_fah_lag2        0.081202     -0.002526      1.000000     -0.002530
# cpi_fah_lag3        0.074286     -0.002513     -0.002530      1.000000
# cpi_fah_lag4        0.076032     -0.002511     -0.002517     -0.002534
# cpi_fah_lag5        0.070362     -0.002570     -0.002515     -0.002521
# cpi_fah_lag6        0.069775     -0.002591     -0.002574     -0.002520
# cpi_fah_lag7        0.067600     -0.002629     -0.002595     -0.002578
# cpi_fah_lag8        0.071768     -0.002641     -0.002633     -0.002600
# cpi_fah_lag9        0.071348     -0.002657     -0.002645     -0.002638
# cpi_fah_lag10       0.074644     -0.002646     -0.002661     -0.002650
# ...

# %%
# Define dependent variable
dep_var = 'cpi_fah'

# Extract unique independent variable names without lag numbers
independent_vars = ['oil_prices', 'ppi_food_feed', 'hourly_wages', 'ppi_food_mfg', 'ppi_cons_food']  # List all base independent vars before lagging

# Loop through each independent variable to find all lagged versions
for var in independent_vars:
    lagged_vars = df.filter(like=var + '_lag').columns.tolist()  # Select all lags dynamically
    var_list = [dep_var] + lagged_vars  # Ensure dependent variable is first
    
    # Compute correlation matrix
    corr_matrix = df[var_list].corr()
    
    # Print the correlation matrix for each independent variable group
    print(f"📊 Correlation Matrix for {var} lags vs {dep_var}")
    print(corr_matrix)
    print("\n" + "="*50 + "\n")  # Separator for readability
# Out:
# 📊 Correlation Matrix for oil_prices lags vs cpi_fah
#                    cpi_fah  oil_prices_lag1  oil_prices_lag2  oil_prices_lag3  \
# cpi_fah           1.000000        -0.003218        -0.003085        -0.002918
# oil_prices_lag1  -0.003218         1.000000        -0.004362        -0.003997
# oil_prices_lag2  -0.003085        -0.004362         1.000000        -0.004373
# oil_prices_lag3  -0.002918        -0.003997        -0.004373         1.000000
# oil_prices_lag4  -0.003026        -0.003794        -0.004007        -0.004383
# oil_prices_lag5  -0.003105        -0.003846        -0.003805        -0.004018
# oil_prices_lag6  -0.003134        -0.003888        -0.003857        -0.003816
# oil_prices_lag7  -0.003125        -0.003943        -0.003898        -0.003867
# oil_prices_lag8  -0.003086        -0.004014        -0.003953        -0.003908
# oil_prices_lag9  -0.003087        -0.003814        -0.004025        -0.003964
# ...

# %%
# Select only columns that contain '_diff' in their names
diff_columns = df.filter(like='_diff').columns

# Compute correlation matrix
corr_matrix = df[diff_columns].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix for _diff Columns")
plt.show()

# %%
# Select only columns that contain '_diff' in their names
diff_columns = df.filter(like='_yoy').columns

# Compute correlation matrix
corr_matrix = df[diff_columns].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix for _YOY Columns")
plt.show()

# %%
# Select the variables to plot (excluding 'date')
var_list = df.filter(like='_yoy').columns.to_list()

# Create a 2-column, 7-row grid of subplots
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(15, 25))  # 2 wide × 7 down

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and plot
for i, col in enumerate(var_list):
    ax = axes[i]  # Select the subplot
    ax.plot(df.index, df[col], label=col, linewidth=2)
    
    # Customize the subplot
    ax.set_title(col, fontsize=12)
    ax.set_xlabel("Date", fontsize=10)
    ax.set_ylabel("Value YOY", fontsize=10)
    ax.grid(True)
    ax.legend()

# Adjust layout for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define dependent variable
dep_var = 'grocery_sales_yoy'

# Define independent variables (YoY versions)
independent_vars = ['cpi_fah_yoy', 'rdi_yoy', 'home_price_yoy', 'cons_sent_yoy', 'unrate_yoy', 'initial_claims_yoy', 'gdp_yoy']

# Loop through each independent variable and plot scatterplots
for var in independent_vars:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df[var], y=df[dep_var])
    plt.xlabel(var)
    plt.ylabel(dep_var)
    plt.title(f'Scatter Plot: {var} vs {dep_var}')
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define dependent variable
dep_var = 'cpi_fah_yoy'

# Define independent variables (YoY versions)
independent_vars = ['oil_prices_yoy', 'ppi_food_feed_yoy', 'hourly_wages_yoy', 'ppi_food_mfg_yoy', 'ppi_cons_food_yoy']

# Loop through each independent variable and plot scatterplots
for var in independent_vars:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df[var], y=df[dep_var])
    plt.xlabel(var)
    plt.ylabel(dep_var)
    plt.title(f'Scatter Plot: {var} vs {dep_var}')
    plt.grid(True)
    plt.show()

# %%
df.to_csv('grocery_dataset_eda.csv', index = True)
